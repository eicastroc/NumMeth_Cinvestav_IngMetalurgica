# %%
import numpy as np
import matplotlib.pyplot as plt
from simult import gaussSeidel
from scipy.optimize import fsolve

# %% [markdown]
# # Métodos numéricos

# %% [markdown]
# <img src="figures/LogoCinvestav.png" style="height:100px" title="Cinvestav">

# %% [markdown]
# **CINVESTAV Unidad Saltillo**
#
# **Curso Propedeutico del Programa de Maestría en Ciencias en Ingeniería Metalúrgica**
#
# Dr. Edgar Ivan Castro Cedeño
#
#
# Enero - Junio 2025
#
# Contacto:
# [edgar.castro@cinvestav.mx](mailto:edgar.castro@cinvestav.mx)

# %% [markdown]
# # 1

# %% [markdown]
# Utilice el método de Gauss-Seidel para resolver el sistema de ecuaciones presentado debajo, considerando una tolerancia de aproximación del $5\%$.

# %% [markdown]
# $$2 x_1 - 6 x_2 - x_3  =  -38$$
# $$-3 x_1 -  x_2 + 7 x_3  =  -34$$
# $$-8 x_1 + x_2 - 2 x_3  =  -20$$

# %% [markdown]
# **(a)** Resuelva sin utilizar relajación.
#
# **(b)** Resuelva utilizando relajación $(\lambda=1.2)$.

# %% [markdown]
# # 2

# %% [markdown]
# Dado el par de ecuaciones no-lineales simultaneas:
#
# $$f(x,y) = 4 - y - 2x^2$$
#
# $$g(x,y) = 8 - y^2 - 4x$$

# %% [markdown]
# **(a)**: Encuentre los dos pares de valores de $x, y$ que satisfacen este sistema.
#
# **(b)**: Usando un rango de estimados iniciales $x=[-6, 6]$, $y=[-6, 6]$, determine que valores iniciales conllevan a cuáles soluciones.

# %% [markdown]
# **Aproximación gráfica**
#
# Como puede verse, se esperaría encontrar cuatro pares de números que nos proporcionen las raíces del sistema.

# %%
fig, ax = plt.subplots(figsize=(6, 4))

x = np.linspace(-6, 6, 61)
y = np.linspace(-6, 6, 61)

ax.plot(x, 4-2*x**2, label='f(x,y)', color='k', ls='-')
ax.plot(2-0.25*y**2, y, label='g(x,y)', color='k', ls='--')
ax.set(xlim=(-6, 6), ylim=(-6, 6),
       xlabel='x', ylabel='y')
ax.legend(loc='upper right')
ax.grid(ls="--")
plt.show()
